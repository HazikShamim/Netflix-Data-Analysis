# %%
# !kaggle datasets download -d shivamb/netflix-shows
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shivamb/netflix-shows
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/1.34M [00:00<?, ?B/s]
#  75%|#######4  | 1.00M/1.34M [00:01<00:00, 861kB/s]
# 100%|##########| 1.34M/1.34M [00:01<00:00, 1.08MB/s]

# %%
import zipfile
zipref=zipfile.ZipFile('netflix-shows.zip')
zipref.extractall()
zipref.close()

# %%
import pandas as pd
df = pd.read_csv('netflix_titles.csv')

# %%
import sqlalchemy as sal 
engine=sal.create_engine('mssql://LAPTOP-5M7652CS\SQLEXPRESS/arman?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()
# Out:
# C:\Users\Hazik\AppData\Local\Temp\ipykernel_46436\673392089.py:3: SAWarning: Unrecognized server version info '17.0.1050.2'.  Some SQL Server features may not function properly.
#   conn=engine.connect()

# %%
df.to_sql('netflix_raw' , con=conn, if_exists='append' , index= False )
# Out:
# 107

# %%
df[df['show_id']=='s5023']
# Out:
#      show_id   type    title       director           cast      country  \
# 5022   s5023  Movie  반드시 잡는다  Hong-seon Kim  Baek Yoon-sik  South Korea
#
#              date_added  release_year rating duration  \
# 5022  February 28, 2018          2017  TV-MA  110 min
#
#                                     listed_in  \
# 5022  Dramas, International Movies, Thrillers
#
#                                             description
# 5022  After people in his town start turning up dead...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
